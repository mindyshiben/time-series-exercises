# %%
import pandas as pd
import requests

# %%
response = requests.get('https://skatingscores.com/usa/men/vincent_zhou/')
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html><html><head><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="Latest Figure Skating Results, Scores, Recaps, Rankings, Standings, Statistics" name="description"/><meta content="figure,skating,isu,results,scores,recaps,rankings,statistics" name="keywords"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><script src="/static/scores/script9.js" type="text/javascript"></script><link href="/static/scores/style77.css" rel="stylesheet" type="text/css"/><link href="/static/scores/i/icon_16x16%402x.png" rel="icon" type="image/png"/><link href="https://skatingscores.com/static/scores/i/icon_512.png" rel="image_src"/><meta content="summary" name="twitter:card"/><meta content="@SkatingScores" name="twitter:site"/><meta content="@SkatingScores" name="twitter:creator"/><meta content="The best resource for Figure Skating scores and stats on the web." name="twitter:title"/><meta content="Brow
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'lxml')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
blog_titles = soup.findAll('title')
print(title.text)
# Out:
# SkatingScores | Figure Skating Results

# %%
pd.read_html('')
# Out:
# <Response [200]>

# %%
import pandas as pd
import numpy as np
import tabula
import PyPDF2

# %%
reader = PyPDF2.PdfFileReader(open('skating_test.pdf', mode='rb'))
m = reader.getNumPages()
print(reader)

# %%
m
# Out:
# 19

# %%
df = tabula.read_pdf('skating_test.pdf', pages='all')

# %%
df = np.array(df)

# %%
df
# Out:
# array([[['1 Anna SHCHERBAKOVA', 'FSR', '35 81.00', ..., '37.14', nan,
#          '0.00'],
#         ['Scores of# Executed Elements', 'Base Ref.Value GOE J1',
#          'J2 J3 J4 J5', ..., 'J7 J8 J9', nan, 'Panel'],
#         ['1 2A', '3.30 1.18 3', '4 4 3 3', ..., '4 3 4', nan, '4.48'],
#         ...,
#         ['Interpretation of the Music', '0.80 9.25',
#          '9.75 9.25 9.50 9.50', ..., '9.25 9.50', nan, '9.39'],
#         ['Judges Total Program Component Score (factored)', nan, nan,
#          ..., nan, nan, '37.14'],
#         ['Deductions:', nan, nan, ..., nan, nan, '0.00']],
#
#        [['2 Rika KIHIRA', 'JPN', '39 79.08', ..., '35.40', nan, '0.00'],
#         ['Scores of# Executed Elements', 'Base Ref.Value GOE J1',
#          'J2 J3 J4 J5', ..., 'J7 J8 J9', nan, 'Panel'],
#         ['1 3Aq', 'q 8.00 0.11 -1', '1 1 -1 1', ..., '1 -1 1', nan,
#          '8.11'],
#         ...,
#         ['Interpretation of the Music', '0.80 8.50',
# ...

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                                                   0                      1  \
# 0                               1 Anna SHCHERBAKOVA                    FSR
# 1                      Scores of# Executed Elements  Base Ref.Value GOE J1
# 2                                              1 2A            3.30 1.18 3
# 3                                              2 3F            5.30 1.97 4
# 4                                          3 CCoSp4            3.50 1.65 4
# 5                                         4 3Lz+3Lo         11.88 x 2.19 3
# 6                                           5 FCSp4            3.20 1.10 3
# 7                                           6 StSq3            3.30 1.32 4
# 8                                            7 LSp4            2.70 1.27 4
# 9                                               NaN                  33.18
# 10                               Program Components                 Factor
# ...

# %%
response = requests.get('http://www.isuresults.com/results/season2021/wc2021/SEG003.htm')
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<html>\r\n<head>\r\n    <title> - Ladies - Short Program</title>\r\n    <meta Http-Equiv="refresh" Content="30">\r\n    <link href="../Styles.css" rel="stylesheet" type="text/css" media="screen">\r\n    <link href="../Print.css" rel="stylesheet" type="text/css" media="print">\r\n    <link rel="shortcut icon" type="image/png" href="../favicon.png">\r\n    <style>\r\n        .disableBiosLink {\r\n            pointer-events: none;\r\n            cursor: default;\r\n            color: inherit;\r\n            text-decoration: inherit;\r\n        }\r\n    </style>\r\n</head>\r\n<body class="PageBody">\r\n    <script src="/results/jquery.js" type="text/javascript"></script>\r\n    <script src="/results/default.js" type="text/javascript"></script>    \r\n    <table class="MainTab" border="0" cellpadding="0" cellspacing="0">\r\n<tr><td><a href="http://www.isu.org"><img src="evt_header.jpg" border="0"></a></td></tr><tr class="EmptyLine14"><td>&nbsp;</td></tr>\r\n<tr class="caption2"><td>Ladie
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'lxml')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html>
# <head>
# <title> - Ladies - Short Program</title>
# <meta content="30" http-equiv="refresh"/>
# <link href="../Styles.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="../Print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="../favicon.png" rel="shortcut icon" type="image/png"/>
# <style>
#         .disableBiosLink {
#             pointer-events: none;
#             cursor: default;
#             color: inherit;
#             text-decoration: inherit;
#         }
#     </style>
# </head>
# <body class="PageBody">
# <script src="/results/jquery.js" type="text/javascript"></script>
# <script src="/results/default.js" type="text/javascript"></script>
# <table border="0" cellpadding="0" cellspacing="0" class="MainTab">
# <tr><td><a href="http://www.isu.org"><img border="0" src="evt_header.jpg"/></a></td></tr><tr class="EmptyLine14"><td> </td></tr>
# ...
